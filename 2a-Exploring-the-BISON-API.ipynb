# %% [markdown]
# ## Using the BISON API
# The USGS provides an API for accessing species observation data. https://bison.usgs.gov/doc/api.jsp
#
# This API is much better documented than the NWIS API, and we'll use it to dig a bit deeper into how the `requests` package can faciliate data access via APIs.

# %% [markdown]
# * We'll begin by replicating the example API call they show on their web page:<br>
# [https://bison.usgs.gov/api/search.json?species=Bison bison&type=scientific_name&start=0&count=1](
# https://bison.usgs.gov/api/search.json?species=Bison%20bison&type=scientific_name&start=0&count=1)

# %%
#First, import the wonderful requests module
import requests

# %% [markdown]
# * Now, we'll deconstruct the example URL into the service URL and parameters, saving the paramters as a dictionary. Note we are just providing a few of the parameters available through the [API](https://bison.usgs.gov/doc/api.jsp#opensearch). We could add more search criteria if we wanted, but for now we just want to grab the first 500 Bison records.

# %%
# Construct the service URL as two components: the service URL and the request parameters
url = 'http://bison.usgs.gov/api/search.json'
params = {'species':'Bison bison',
          'type':'scientific_name',
          'start':'0',
          'count':'500'
         }

# %% [markdown]
# * With the components set as variables, we use the `requests.get()` function to send our request off to the server at the address provided, storing the servers response as a variable called `response`.

# %%
#Send the request to the server and store the response as a variable
response = requests.get(url,params)

# %% [markdown]
# * This response object contains a number of properties and methods. Let's have a look at the reponse in raw text format.

# %%
#View the reponse in text format
print(response.text)
# Out:
# {"occurrences":{"legend":{"fossil":1354,"observation":2247,"centroid":1,"specimen":1017}},"total":4618,"searchTime":184,"offset":0,"data":[{"geo":"Yes","provider":"iNaturalist.org","name":"Bison bison","decimalLongitude":"-112.97224426269531","decimalLatitude":"53.55277633666992","occurrenceID":"1453380369","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"iNaturalist.org","name":"Bison bison","decimalLongitude":"-110.76473236083984","decimalLatitude":"43.64556884765625","occurrenceID":"1024331790","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"Museum of Comparative Zoology, Harvard University","name":"Bison bison","decimalLongitude":"-84.72786712646484","decimalLatitude":"38.96986389160156","occurrenceID":"2461345968","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Fossil"},{"geo":"Yes","provider":"iNaturalist.org","name":"Bison bison","decimalLongitude":"-103.40538024902344","decimalLatitude":"43.714542388916016","occurrenceID":"891750841","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"iNaturalist.org","name":"Bison bison","decimalLongitude":"-111.41018676757812","decimalLatitude":"38.33570098876953","occurrenceID":"2574088021","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"University of Wyoming Museum of Vertebrates","name":"Bison bison","decimalLongitude":"-110.45471954345703","decimalLatitude":"44.643890380859375","occurrenceID":"897118223","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"Yes","provider":"University of Alaska Museum of the North","name":"Bison bison","decimalLongitude":"-145.6666717529297","decimalLatitude":"64.08333587646484","occurrenceID":"897052681","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"No","provider":"California State University, Chico Vertebrate Museum","name":"Bison bison","occurrenceID":"1065082283","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"Yes","provider":"University of Arkansas Collections Facility, UAFMC","name":"Bison bison","decimalLongitude":"-101.04034423828125","decimalLatitude":"46.11265182495117","occurrenceID":"919971033","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"No","provider":"National Museum of Natural History, Smithsonian Institution","name":"Bison bison","occurrenceID":"1318732613","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"Yes","provider":"iNaturalist.org","name":"Bison bison","decimalLongitude":"-110.6800537109375","decimalLatitude":"44.91789245605469","occurrenceID":"2251905047","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"iNaturalist.org","name":"Bison bison","decimalLongitude":"-98.71973419189453","decimalLatitude":"34.731868743896484","occurrenceID":"2609085258","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"No","provider":"National Museum of Natural History, Smithsonian Institution","name":"Bison bison","occurrenceID":"1319869112","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"No","provider":"Cornell Lab of Ornithology","name":"Bison bison","occurrenceID":"1147227975","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"No","provider":"Cornell Lab of Ornithology","name":"Bison bison","occurrenceID":"1147241384","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"No","provider":"Cornel ...

# %% [markdown]
# **Yikes**, that's much less readable than the NWIS output!
#
# Well, that's because the response from the BISON server is in **JSON** format. JSON, short for *JavaScript Object Notation*, is a text document that stores information in `key`:`value` pairs, *much like a Python dictionary*. Still, it's a raw text object, but one that we convert into a Python dictionary using `requests`'s `json()` function to convert the servers response into a Python dictionary.

# %%
#Convert the response 
data = response.json()
type(data)
# Out:
# dict

# %% [markdown]
# * Ok, if it's a dictionary, what are it's keys?

# %%
#List the keys in the returned JSON object
data.keys()
# Out:
# dict_keys(['occurrences', 'total', 'searchTime', 'offset', 'data', 'species', 'eezs', 'itemsPerPage', 'counties', 'type', 'georeferenced', 'states'])

# %% [markdown]
# * What are the values linked with the 'data' key?

# %%
#Show the value associated with the `data` key
data['data']
# Out:
# [{'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.97224426269531',
#   'decimalLatitude': '53.55277633666992',
#   'occurrenceID': '1453380369',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.76473236083984',
#   'decimalLatitude': '43.64556884765625',
#   'occurrenceID': '1024331790',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'decimalLongitude': '-84.72786712646484',
#   'decimalLatitude': '38.96986389160156',
#   'occurrenceID': '2461345968',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.40538024902344',
#   'decimalLatitude': '43.714542388916016',
#   'occurrenceID': '891750841',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-111.41018676757812',
#   'decimalLatitude': '38.33570098876953',
#   'occurrenceID': '2574088021',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'University of Wyoming Museum of Vertebrates',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.45471954345703',
#   'decimalLatitude': '44.643890380859375',
#   'occurrenceID': '897118223',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'University of Alaska Museum of the North',
#   'name': 'Bison bison',
#   'decimalLongitude': '-145.6666717529297',
#   'decimalLatitude': '64.08333587646484',
#   'occurrenceID': '897052681',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'California State University, Chico Vertebrate Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '1065082283',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'University of Arkansas Collections Facility, UAFMC',
#   'name': 'Bison bison',
#   'decimalLongitude': '-101.04034423828125',
#   'decimalLatitude': '46.11265182495117',
#   'occurrenceID': '919971033',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1318732613',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.6800537109375',
#   'decimalLatitude': '44.91789245605469',
#   'occurrenceID': '2251905047',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-98.71973419189453',
#   'decimalLatitude': '34.731868743896484',
#   'occurrenceID': '2609085258',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1319869112',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '1147227975',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '1147241384',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '1147038974',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '1147098831',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1804051054',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Utah Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '1656064950',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '2461347653',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '2461296794',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '2461296797',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '2461346867',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'James R. Slater Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '812649672',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Field Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '665849580',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Yale University Peabody Museum',
#   'name': 'Bison bison',
#   'decimalLongitude': '-101.59110260009766',
#   'decimalLatitude': '38.911399841308594',
#   'occurrenceID': '1039519412',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Yale University Peabody Museum',
#   'name': 'Bison bison',
#   'decimalLongitude': '-101.59110260009766',
#   'decimalLatitude': '38.911399841308594',
#   'occurrenceID': '1039519913',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Museum of Texas Tech University (TTU)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-101.99800109863281',
#   'decimalLatitude': '33.68899917602539',
#   'occurrenceID': '911671417',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Museum of Texas Tech University (TTU)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-101.99800109863281',
#   'decimalLatitude': '33.68899917602539',
#   'occurrenceID': '911671363',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.9105453491211',
#   'decimalLatitude': '44.4246711730957',
#   'occurrenceID': '2366131004',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.92009735107422',
#   'decimalLatitude': '44.64444351196289',
#   'occurrenceID': '2397567791',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.13763427734375',
#   'decimalLatitude': '40.859981536865234',
#   'occurrenceID': '2460143012',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.9223403930664',
#   'decimalLatitude': '44.433589935302734',
#   'occurrenceID': '2397668197',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'decimalLongitude': '-84.72786712646484',
#   'decimalLatitude': '38.96986389160156',
#   'occurrenceID': '2461347037',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.14917755126953',
#   'decimalLatitude': '44.905643463134766',
#   'occurrenceID': '2597876552',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1319119722',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Alberta Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '1209665705',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '891327391',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1318459566',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1322095913',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '1234604740',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '1234611998',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '1234605767',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1321459520',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1319108604',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-100.19963073730469',
#   'decimalLatitude': '50.8294792175293',
#   'occurrenceID': '1914246537',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.8346939086914',
#   'decimalLatitude': '53.59470748901367',
#   'occurrenceID': '1883555908',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-100.2008056640625',
#   'decimalLatitude': '50.83022689819336',
#   'occurrenceID': '2005374109',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-127.46961975097656',
#   'decimalLatitude': '59.795589447021484',
#   'occurrenceID': '2445081006',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-100.2241439819336',
#   'decimalLatitude': '50.767276763916016',
#   'occurrenceID': '1586107187',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1319859294',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-125.9528579711914',
#   'decimalLatitude': '59.346961975097656',
#   'occurrenceID': '2596043626',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'naturgucker.de',
#   'name': 'Bison bison',
#   'decimalLongitude': '-100.21188354492188',
#   'decimalLatitude': '50.80156326293945',
#   'occurrenceID': '2251770819',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.84077453613281',
#   'decimalLatitude': '53.595008850097656',
#   'occurrenceID': '2294537180',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.83432006835938',
#   'decimalLatitude': '53.59602355957031',
#   'occurrenceID': '2294607667',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.8604736328125',
#   'decimalLatitude': '53.603477478027344',
#   'occurrenceID': '1978826146',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'European Molecular Biology Laboratory (EMBL)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-105.7699966430664',
#   'decimalLatitude': '53.20000076293945',
#   'occurrenceID': '2311088405',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-128.18304443359375',
#   'decimalLatitude': '59.95634078979492',
#   'occurrenceID': '1978466085',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-126.68276977539062',
#   'decimalLatitude': '59.60340881347656',
#   'occurrenceID': '2294622992',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-126.84642791748047',
#   'decimalLatitude': '59.64025115966797',
#   'occurrenceID': '2252029988',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1317830482',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-126.6215591430664',
#   'decimalLatitude': '59.63129806518555',
#   'occurrenceID': '2465278417',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'University of British Columbia',
#   'name': 'Bison bison',
#   'decimalLongitude': '-127.04759216308594',
#   'decimalLatitude': '54.694950103759766',
#   'occurrenceID': '1291998314',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.84147644042969',
#   'decimalLatitude': '53.59416198730469',
#   'occurrenceID': '1880533827',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': "Muséum d'Histoire Naturelle de Bourges",
#   'name': 'Bison bison',
#   'decimalLongitude': '-75.66999816894531',
#   'decimalLatitude': '45.400001525878906',
#   'occurrenceID': '440648970',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826485016',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826503155',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826487830',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826468420',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826475878',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826469619',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'European Molecular Biology Laboratory (EMBL)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-105.7699966430664',
#   'decimalLatitude': '53.20000076293945',
#   'occurrenceID': '2308090287',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826498631',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826474667',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826463834',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826482107',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826499373',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826489690',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826492641',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826484954',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826501624',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826494120',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826472130',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826496291',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826510856',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826464368',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826497922',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826466668',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826500454',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826499600',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826502655',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826480298',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826501509',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826470479',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826473147',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826464959',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826505174',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826502815',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826509041',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826487635',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826471282',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826476340',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826477886',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826465536',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826496014',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826500667',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826476155',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826498847',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826476319',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826467715',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826467125',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826475435',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826499618',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826511994',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826479075',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826498467',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826480978',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826497066',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826509481',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826468576',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826495407',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826478823',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826506657',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826471385',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826475179',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826470060',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826471528',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826471215',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826490966',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826476584',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826488831',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826496625',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826512375',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826477540',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826464522',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826482474',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826490776',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826465609',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826468599',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826470053',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826513753',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826488473',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826512646',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826469580',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1826474651',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-122.85006713867188',
#   'decimalLatitude': '59.80508804321289',
#   'occurrenceID': '1802669736',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'naturgucker.de',
#   'name': 'Bison bison',
#   'decimalLongitude': '-136.9957275390625',
#   'decimalLatitude': '61.078712463378906',
#   'occurrenceID': '1038536955',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.08333587646484',
#   'decimalLatitude': '58.58333206176758',
#   'occurrenceID': '1804054433',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-127.51959228515625',
#   'decimalLatitude': '59.964599609375',
#   'occurrenceID': '2366156075',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-107.56211853027344',
#   'decimalLatitude': '49.201194763183594',
#   'occurrenceID': '2397613601',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'European Molecular Biology Laboratory (EMBL)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-118.51000213623047',
#   'decimalLatitude': '54.709999084472656',
#   'occurrenceID': '2304355933',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'European Molecular Biology Laboratory (EMBL)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-113.3499984741211',
#   'decimalLatitude': '53.599998474121094',
#   'occurrenceID': '2304183660',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.84222412109375',
#   'decimalLatitude': '53.597618103027344',
#   'occurrenceID': '2331885758',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.85799407958984',
#   'decimalLatitude': '53.63438415527344',
#   'occurrenceID': '1883938004',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-127.42623901367188',
#   'decimalLatitude': '59.890899658203125',
#   'occurrenceID': '2445046093',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-113.86748504638672',
#   'decimalLatitude': '49.126739501953125',
#   'occurrenceID': '2603453371',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.84376525878906',
#   'decimalLatitude': '53.600040435791016',
#   'occurrenceID': '1890708170',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1804060298',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.67666625976562',
#   'decimalLatitude': '50.04083251953125',
#   'occurrenceID': '1804098771',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1804056663',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.23332977294922',
#   'decimalLatitude': '59.54999923706055',
#   'occurrenceID': '1804072097',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.23332977294922',
#   'decimalLatitude': '59.54999923706055',
#   'occurrenceID': '1804041914',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1804062197',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1804068841',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1804054549',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1804060568',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.08333587646484',
#   'decimalLatitude': '58.58333206176758',
#   'occurrenceID': '1804086894',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'occurrenceID': '1804048887',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.08333587646484',
#   'decimalLatitude': '58.58333206176758',
#   'occurrenceID': '1804083933',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Canadian Museum of Nature',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.08333587646484',
#   'decimalLatitude': '58.58333206176758',
#   'occurrenceID': '1804045578',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.8547592163086',
#   'decimalLatitude': '53.59415054321289',
#   'occurrenceID': '2273271398',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-127.50507354736328',
#   'decimalLatitude': '59.963958740234375',
#   'occurrenceID': '2397619408',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-116.57649993896484',
#   'decimalLatitude': '53.93326950073242',
#   'occurrenceID': '2465095711',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-126.08333587646484',
#   'decimalLatitude': '59.41666793823242',
#   'occurrenceID': '2550065642',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.82555389404297',
#   'decimalLatitude': '53.66166687011719',
#   'occurrenceID': '1850953328',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'naturgucker.de',
#   'name': 'Bison bison',
#   'decimalLongitude': '-100.21188354492188',
#   'decimalLatitude': '50.80156326293945',
#   'occurrenceID': '2251770811',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'European Molecular Biology Laboratory (EMBL)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-120.94000244140625',
#   'decimalLatitude': '56.27000045776367',
#   'occurrenceID': '2304656137',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'European Molecular Biology Laboratory (EMBL)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-113.3499984741211',
#   'decimalLatitude': '53.599998474121094',
#   'occurrenceID': '2306270104',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'European Molecular Biology Laboratory (EMBL)',
#   'name': 'Bison bison',
#   'decimalLongitude': '-120.94000244140625',
#   'decimalLatitude': '56.27000045776367',
#   'occurrenceID': '2304592699',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '1321354570',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-126.10693359375',
#   'decimalLatitude': '59.42493438720703',
#   'occurrenceID': '2251874851',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.83052825927734',
#   'decimalLatitude': '53.657371520996094',
#   'occurrenceID': '2429592594',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'naturgucker.de',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.89447784423828',
#   'decimalLatitude': '53.60799026489258',
#   'occurrenceID': '2273627202',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'naturgucker.de',
#   'name': 'Bison bison',
#   'decimalLongitude': '-100.21188354492188',
#   'decimalLatitude': '50.80156326293945',
#   'occurrenceID': '920750126',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-126.25788116455078',
#   'decimalLatitude': '59.45316696166992',
#   'occurrenceID': '899948623',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.83570861816406',
#   'decimalLatitude': '53.65803527832031',
#   'occurrenceID': '1948783981',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-125.98039245605469',
#   'decimalLatitude': '59.383365631103516',
#   'occurrenceID': '923911342',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Bison bison',
#   'decimalLongitude': '-141.98265075683594',
#   'decimalLatitude': '60.65416717529297',
#   'occurrenceID': '2638273359',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Bison bison',
#   'decimalLongitude': '-102.64493560791016',
#   'decimalLatitude': '43.61368942260742',
#   'occurrenceID': '2638273360',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.49008178710938',
#   'decimalLatitude': '44.581298828125',
#   'occurrenceID': '2638273361',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
# ...
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.4439926147461',
#   'decimalLatitude': '44.91856002807617',
#   'occurrenceID': '1571149254',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.47260284423828',
#   'decimalLatitude': '44.49633026123047',
#   'occurrenceID': '2294637563',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.38381958007812',
#   'decimalLatitude': '46.936920166015625',
#   'occurrenceID': '1890048410',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.40216827392578',
#   'decimalLatitude': '44.70134735107422',
#   'occurrenceID': '1584436384',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.14395904541016',
#   'decimalLatitude': '40.89601516723633',
#   'occurrenceID': '2429593967',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.69960021972656',
#   'decimalLatitude': '43.72079849243164',
#   'occurrenceID': '1291153074',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.26058197021484',
#   'decimalLatitude': '44.489585876464844',
#   'occurrenceID': '1850911038',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.95356750488281',
#   'decimalLatitude': '44.54471969604492',
#   'occurrenceID': '1571122031',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.75325012207031',
#   'decimalLatitude': '45.14891815185547',
#   'occurrenceID': '2557740475',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-118.41631317138672',
#   'decimalLatitude': '33.38788604736328',
#   'occurrenceID': '1703158084',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.53871154785156',
#   'decimalLatitude': '46.978965759277344',
#   'occurrenceID': '2294681613',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-82.30435180664062',
#   'decimalLatitude': '29.60124969482422',
#   'occurrenceID': '2543101708',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.52140808105469',
#   'decimalLatitude': '44.61247253417969',
#   'occurrenceID': '2626526394',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.24504089355469',
#   'decimalLatitude': '44.967002868652344',
#   'occurrenceID': '2005319580',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-96.95574951171875',
#   'decimalLatitude': '34.502357482910156',
#   'occurrenceID': '2596222649',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.44015502929688',
#   'decimalLatitude': '43.879974365234375',
#   'occurrenceID': '891069699',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-118.40660095214844',
#   'decimalLatitude': '33.385719299316406',
#   'occurrenceID': '1841301823',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.52880859375',
#   'decimalLatitude': '46.93851089477539',
#   'occurrenceID': '1807308052',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.26324462890625',
#   'decimalLatitude': '44.88705825805664',
#   'occurrenceID': '2005319595',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.86953735351562',
#   'decimalLatitude': '44.51020812988281',
#   'occurrenceID': '2626134770',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.4906234741211',
#   'decimalLatitude': '46.9686164855957',
#   'occurrenceID': '1946320648',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-89.34463500976562',
#   'decimalLatitude': '41.891056060791016',
#   'occurrenceID': '2619919314',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.8489990234375',
#   'decimalLatitude': '44.41891860961914',
#   'occurrenceID': '1571118499',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.2423324584961',
#   'decimalLatitude': '41.02186584472656',
#   'occurrenceID': '2456543464',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-104.86566162109375',
#   'decimalLatitude': '39.83835220336914',
#   'occurrenceID': '2242970697',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.44623565673828',
#   'decimalLatitude': '46.96760177612305',
#   'occurrenceID': '1848776456',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.51759338378906',
#   'decimalLatitude': '44.53132247924805',
#   'occurrenceID': '2626324517',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.10932159423828',
#   'decimalLatitude': '44.400203704833984',
#   'occurrenceID': '2012954029',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.38722229003906',
#   'decimalLatitude': '41.072654724121094',
#   'occurrenceID': '2447955205',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.50262451171875',
#   'decimalLatitude': '46.95427703857422',
#   'occurrenceID': '2397667325',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.63933563232422',
#   'decimalLatitude': '44.61311721801758',
#   'occurrenceID': '1265558522',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.27810668945312',
#   'decimalLatitude': '41.078102111816406',
#   'occurrenceID': '2574000848',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.82185363769531',
#   'decimalLatitude': '44.40983581542969',
#   'occurrenceID': '2429602519',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.45570373535156',
#   'decimalLatitude': '44.91457748413086',
#   'occurrenceID': '1933560746',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-104.84281158447266',
#   'decimalLatitude': '39.83441162109375',
#   'occurrenceID': '2580110425',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.23490905761719',
#   'decimalLatitude': '44.947261810302734',
#   'occurrenceID': '1572383487',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.55523681640625',
#   'decimalLatitude': '44.58211898803711',
#   'occurrenceID': '1306591370',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.2256851196289',
#   'decimalLatitude': '44.20097732543945',
#   'occurrenceID': '1847578016',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.19094848632812',
#   'decimalLatitude': '44.982627868652344',
#   'occurrenceID': '2294520025',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.60618591308594',
#   'decimalLatitude': '43.69989013671875',
#   'occurrenceID': '2626391265',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.2685317993164',
#   'decimalLatitude': '40.81495666503906',
#   'occurrenceID': '2596052494',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-102.41483306884766',
#   'decimalLatitude': '43.893798828125',
#   'occurrenceID': '1092906888',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.48793029785156',
#   'decimalLatitude': '44.79344940185547',
#   'occurrenceID': '2294533249',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.2636489868164',
#   'decimalLatitude': '44.40939712524414',
#   'occurrenceID': '2626096641',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.00901794433594',
#   'decimalLatitude': '44.81808090209961',
#   'occurrenceID': '2311395926',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.51817321777344',
#   'decimalLatitude': '44.6897087097168',
#   'occurrenceID': '2540792258',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.47764587402344',
#   'decimalLatitude': '46.98243713378906',
#   'occurrenceID': '1899783655',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.7610855102539',
#   'decimalLatitude': '44.52174758911133',
#   'occurrenceID': '891029610',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-106.99327850341797',
#   'decimalLatitude': '33.333805084228516',
#   'occurrenceID': '2397560447',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.65933227539062',
#   'decimalLatitude': '43.740753173828125',
#   'occurrenceID': '2244225920',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-112.39334869384766',
#   'decimalLatitude': '41.077693939208984',
#   'occurrenceID': '1306572700',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-100.03150177001953',
#   'decimalLatitude': '42.73929214477539',
#   'occurrenceID': '2252065444',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-110.60688018798828',
#   'decimalLatitude': '44.82806396484375',
#   'occurrenceID': '2611072032',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'iNaturalist.org',
#   'name': 'Bison bison',
#   'decimalLongitude': '-103.35539245605469',
#   'decimalLatitude': '43.73323059082031',
#   'occurrenceID': '1978468124',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'}]

# %% [markdown]
# * Oh, it's a list of occurrences! Let's examine the first one...

# %%
#Display the first "data" value
data['data'][0]
# Out:
# {'geo': 'Yes',
#  'provider': 'iNaturalist.org',
#  'name': 'Bison bison',
#  'decimalLongitude': '-112.97224426269531',
#  'decimalLatitude': '53.55277633666992',
#  'occurrenceID': '1453380369',
#  'common_name': 'bison, American bison, American Bison, Bisonte americano',
#  'basis': 'Observation'}

# %% [markdown]
# * We see it's a dictionary too! Let's list the `decimalLatitude` item value...

# %%
#We can get the latitude of the record from it's `decimalLatitude` key
data['data'][0]['decimalLatitude']
# Out:
# '53.55277633666992'

# %% [markdown]
# ► **So** we see the Bison observations are stored as list of dictionaries which are accessed within the `data` key in the results dictionary generated from the JSON response to our API request. (Phew!)
#
# * With a bit more code we can loop through all the data records and print out the lat and long coordinates...

# %%
#Loop thorough each observation and print the lat and long values
for observation in data['data']:
    if observation['geo'] == 'Yes':
        print (observation['decimalLatitude'],observation['decimalLongitude'])
# Out:
# 53.55277633666992 -112.97224426269531
# 43.64556884765625 -110.76473236083984
# 38.96986389160156 -84.72786712646484
# 43.714542388916016 -103.40538024902344
# 38.33570098876953 -111.41018676757812
# 44.643890380859375 -110.45471954345703
# 64.08333587646484 -145.6666717529297
# 46.11265182495117 -101.04034423828125
# 44.91789245605469 -110.6800537109375
# 34.731868743896484 -98.71973419189453
# 38.911399841308594 -101.59110260009766
# 38.911399841308594 -101.59110260009766
# 33.68899917602539 -101.99800109863281
# 33.68899917602539 -101.99800109863281
# 44.4246711730957 -110.9105453491211
# 44.64444351196289 -110.92009735107422
# 40.859981536865234 -112.13763427734375
# 44.433589935302734 -110.9223403930664
# 38.96986389160156 -84.72786712646484
# 44.905643463134766 -110.14917755126953
# 50.8294792175293 -100.19963073730469
# 53.59470748901367 -112.8346939086914
# 50.83022689819336 -100.2008056640625
# 59.795589447021484 -127.46961975097656
# 50.767276763916016 -100.2241439819336
# 59.346961975097656 -125.9528579711914
# 50.80156326293945 -100.21188354492188
# 53.595008850097656 -112.84077453613281
# 53.59602355957031 -112.83432006835938
# 53.603477478027344 -112.8604736328125
# 53.20000076293945 -105.7699966430664
# 59.95634078979492 -128.18304443359375
# 59.60340881347656 -126.68276977539062
# 59.64025115966797 -126.84642791748047
# 59.63129806518555 -126.6215591430664
# 54.694950103759766 -127.04759216308594
# 53.59416198730469 -112.84147644042969
# 45.400001525878906 -75.66999816894531
# 53.20000076293945 -105.7699966430664
# 59.80508804321289 -122.85006713867188
# 61.078712463378906 -136.9957275390625
# 58.58333206176758 -112.08333587646484
# 59.964599609375 -127.51959228515625
# 49.201194763183594 -107.56211853027344
# 54.709999084472656 -118.51000213623047
# 53.599998474121094 -113.3499984741211
# 53.597618103027344 -112.84222412109375
# 53.63438415527344 -112.85799407958984
# 59.890899658203125 -127.42623901367188
# 49.126739501953125 -113.86748504638672
# 53.600040435791016 -112.84376525878906
# 50.04083251953125 -110.67666625976562
# 59.54999923706055 -112.23332977294922
# 59.54999923706055 -112.23332977294922
# 58.58333206176758 -112.08333587646484
# 58.58333206176758 -112.08333587646484
# 58.58333206176758 -112.08333587646484
# 53.59415054321289 -112.8547592163086
# 59.963958740234375 -127.50507354736328
# 44.48409652709961 -110.54882049560547
# 43.684635162353516 -103.35247802734375
# 39.812828063964844 -104.82283020019531
# 33.439048767089844 -118.4953842163086
# 43.919742584228516 -110.61662292480469
# 47.39784240722656 -114.32476806640625
# 43.61731719970703 -110.75006103515625
# 43.60457992553711 -103.42134094238281
# 43.538631439208984 -103.65585327148438
# 44.65256881713867 -110.43033599853516
# 33.38788604736328 -118.41631317138672
# 36.36309814453125 -112.1216812133789
# 44.83346176147461 -110.21241760253906
# 35.24562072753906 -112.21435546875
# 33.38444519042969 -118.40258026123047
# 44.91856002807617 -110.4439926147461
# 44.49633026123047 -110.47260284423828
# 46.936920166015625 -103.38381958007812
# 44.70134735107422 -110.40216827392578
# 40.89601516723633 -112.14395904541016
# 43.72079849243164 -110.69960021972656
# 44.489585876464844 -110.26058197021484
# 44.54471969604492 -110.95356750488281
# 45.14891815185547 -110.75325012207031
# 33.38788604736328 -118.41631317138672
# 46.978965759277344 -103.53871154785156
# 29.60124969482422 -82.30435180664062
# 44.61247253417969 -110.52140808105469
# 44.967002868652344 -110.24504089355469
# 34.502357482910156 -96.95574951171875
# 43.879974365234375 -110.44015502929688
# 33.385719299316406 -118.40660095214844
# 46.93851089477539 -103.52880859375
# 44.88705825805664 -110.26324462890625
# 44.51020812988281 -110.86953735351562
# 46.9686164855957 -103.4906234741211
# 41.891056060791016 -89.34463500976562
# 44.41891860961914 -110.8489990234375
# 41.02186584472656 -112.2423324584961
# 39.83835220336914 -104.86566162109375
# 46.96760177612305 -103.44623565673828
# 44.53132247924805 -110.51759338378906
# 44.400203704833984 -110.10932159423828
# 41.072654724121094 -112.38722229003906
# 46.95427703857422 -103.50262451171875
# 44.61311721801758 -110.63933563232422
# 41.078102111816406 -112.27810668945312
# 44.40983581542969 -110.82185363769531
# 44.91457748413086 -110.45570373535156
# 39.83441162109375 -104.84281158447266
# 44.947261810302734 -110.23490905761719
# 44.58211898803711 -110.55523681640625
# 44.20097732543945 -110.2256851196289
# 44.982627868652344 -110.19094848632812
# 43.69989013671875 -110.60618591308594
# 40.81495666503906 -112.2685317993164
# 43.893798828125 -102.41483306884766
# 44.79344940185547 -110.48793029785156
# 44.40939712524414 -110.2636489868164
# 44.81808090209961 -110.00901794433594
# 44.6897087097168 -110.51817321777344
# 46.98243713378906 -103.47764587402344
# 44.52174758911133 -110.7610855102539
# 33.333805084228516 -106.99327850341797
# 43.740753173828125 -110.65933227539062
# 41.077693939208984 -112.39334869384766
# 42.73929214477539 -100.03150177001953
# 44.82806396484375 -110.60688018798828
# 43.73323059082031 -103.35539245605469

# %% [markdown]
# <details>
#     <summary>
# ► If the above throws an error, can you debug it? HINT: the `geo` tag indicates whether coordinate info exist for the record...
#     </summary>
#     <pre><code>
# #Loop thorough each observation and print the lat and long values
# for observation in data['data']:
#     if(observation['geo'] == 'Yes'):
#         print (observation['decimalLatitude'],observation['decimalLongitude'])
#     </code></pre>
# </details>

# %%
#Loop thorough each observation and print the lat and long values
# 44.70134735107422 -110.40216827392578
# 40.89601516723633 -112.14395904541016
# 43.72079849243164 -110.69960021972656
# 44.489585876464844 -110.26058197021484
# 44.54471969604492 -110.95356750488281
# 45.14891815185547 -110.75325012207031
# 33.38788604736328 -118.41631317138672
# 46.978965759277344 -103.53871154785156
# 29.60124969482422 -82.30435180664062
# 44.61247253417969 -110.52140808105469
# 44.967002868652344 -110.24504089355469
# 34.502357482910156 -96.95574951171875
# 43.879974365234375 -110.44015502929688
# 33.385719299316406 -118.40660095214844
# 46.93851089477539 -103.52880859375
# 44.88705825805664 -110.26324462890625
# 44.51020812988281 -110.86953735351562
# 46.9686164855957 -103.4906234741211
# 41.891056060791016 -89.34463500976562
# 44.41891860961914 -110.8489990234375
# 41.02186584472656 -112.2423324584961
# 39.83835220336914 -104.86566162109375
# 46.96760177612305 -103.44623565673828
# 44.53132247924805 -110.51759338378906
# 44.400203704833984 -110.10932159423828
# 41.072654724121094 -112.38722229003906
# 46.95427703857422 -103.50262451171875
# 44.61311721801758 -110.63933563232422
# 41.078102111816406 -112.27810668945312
# 44.40983581542969 -110.82185363769531
# 44.91457748413086 -110.45570373535156
# 39.83441162109375 -104.84281158447266
# 44.947261810302734 -110.23490905761719
# 44.58211898803711 -110.55523681640625
# 44.20097732543945 -110.2256851196289
# 44.982627868652344 -110.19094848632812
# 43.69989013671875 -110.60618591308594
# 40.81495666503906 -112.2685317993164
# 43.893798828125 -102.41483306884766
# 44.79344940185547 -110.48793029785156
# 44.40939712524414 -110.2636489868164
# 44.81808090209961 -110.00901794433594
# 44.6897087097168 -110.51817321777344
# 46.98243713378906 -103.47764587402344
# 44.52174758911133 -110.7610855102539
# 33.333805084228516 -106.99327850341797
# 43.740753173828125 -110.65933227539062
# 41.077693939208984 -112.39334869384766
# 42.73929214477539 -100.03150177001953
# 44.82806396484375 -110.60688018798828
# 43.73323059082031 -103.35539245605469

# %% [markdown]
# ### Using Pandas to streamline the process...
# Pandas can create a dataframe directly from dictionary values.

# %%
import pandas as pd
df = pd.DataFrame(data['data'])
df.head()
# Out:
#    geo                                           provider         name  \
# 0  Yes                                    iNaturalist.org  Bison bison
# 1  Yes                                    iNaturalist.org  Bison bison
# 2  Yes  Museum of Comparative Zoology, Harvard University  Bison bison
# 3  Yes                                    iNaturalist.org  Bison bison
# 4  Yes                                    iNaturalist.org  Bison bison
#
#       decimalLongitude     decimalLatitude occurrenceID  \
# 0  -112.97224426269531   53.55277633666992   1453380369
# 1  -110.76473236083984   43.64556884765625   1024331790
# 2   -84.72786712646484   38.96986389160156   2461345968
# 3  -103.40538024902344  43.714542388916016    891750841
# 4  -111.41018676757812   38.33570098876953   2574088021
#
#                                          common_name        basis
# 0  bison, American bison, American Bison, Bisonte...  Observation
# 1  bison, American bison, American Bison, Bisonte...  Observation
# 2  bison, American bison, American Bison, Bisonte...       Fossil
# 3  bison, American bison, American Bison, Bisonte...  Observation
# 4  bison, American bison, American Bison, Bisonte...  Observation

# %% [markdown]
# So now we can use our Panda's know-how to do some nifty analyses, including subsetting records for a specific provider.
# * First we'll get a list of unique providers found in the data

# %%
#Generate a list of providers
df.provider.unique()
# Out:
# array(['iNaturalist.org',
#        'Museum of Comparative Zoology, Harvard University',
#        'University of Wyoming Museum of Vertebrates',
#        'University of Alaska Museum of the North',
#        'California State University, Chico Vertebrate Museum',
#        'University of Arkansas Collections Facility, UAFMC',
#        'National Museum of Natural History, Smithsonian Institution',
#        'Cornell Lab of Ornithology', 'Canadian Museum of Nature',
#        'Utah Museum of Natural History',
#        'James R. Slater Museum of Natural History', 'Field Museum',
#        'Yale University Peabody Museum',
#        'Museum of Texas Tech University (TTU)',
#        'University of Alberta Museums', 'Royal Ontario Museum',
#        'naturgucker.de', 'European Molecular Biology Laboratory (EMBL)',
#        'University of British Columbia',
#        "Muséum d'Histoire Naturelle de Bourges", 'BISON',
#        'Texas A&M University Biodiversity Research and Teaching Collections',
#        'Natural History Museum, University of Oslo',
#        'Humboldt State University',
#        'Sam Noble Oklahoma Museum of Natural History',
#        'Michigan State University Museum'], dtype=object)

# %% [markdown]
# * Now, we'll subset the rows that include that provider...

# %%
df.query("provider == 'iNaturalist.org'")
# Out:
#      geo         provider         name     decimalLongitude  \
# 0    Yes  iNaturalist.org  Bison bison  -112.97224426269531
# 1    Yes  iNaturalist.org  Bison bison  -110.76473236083984
# 3    Yes  iNaturalist.org  Bison bison  -103.40538024902344
# 4    Yes  iNaturalist.org  Bison bison  -111.41018676757812
# 10   Yes  iNaturalist.org  Bison bison   -110.6800537109375
# ..   ...              ...          ...                  ...
# 495  Yes  iNaturalist.org  Bison bison  -110.65933227539062
# 496  Yes  iNaturalist.org  Bison bison  -112.39334869384766
# 497  Yes  iNaturalist.org  Bison bison  -100.03150177001953
# 498  Yes  iNaturalist.org  Bison bison  -110.60688018798828
# 499  Yes  iNaturalist.org  Bison bison  -103.35539245605469
#
#         decimalLatitude occurrenceID  \
# 0     53.55277633666992   1453380369
# 1     43.64556884765625   1024331790
# 3    43.714542388916016    891750841
# 4     38.33570098876953   2574088021
# 10    44.91789245605469   2251905047
# ..                  ...          ...
# 495  43.740753173828125   2244225920
# 496  41.077693939208984   1306572700
# 497   42.73929214477539   2252065444
# 498   44.82806396484375   2611072032
# 499   43.73323059082031   1978468124
#
#                                            common_name        basis
# 0    bison, American bison, American Bison, Bisonte...  Observation
# 1    bison, American bison, American Bison, Bisonte...  Observation
# 3    bison, American bison, American Bison, Bisonte...  Observation
# 4    bison, American bison, American Bison, Bisonte...  Observation
# 10   bison, American bison, American Bison, Bisonte...  Observation
# ..                                                 ...          ...
# 495  bison, American bison, American Bison, Bisonte...  Observation
# 496  bison, American bison, American Bison, Bisonte...  Observation
# 497  bison, American bison, American Bison, Bisonte...  Observation
# 498  bison, American bison, American Bison, Bisonte...  Observation
# 499  bison, American bison, American Bison, Bisonte...  Observation
#
# [231 rows x 8 columns]

# %%
df.dtypes
# Out:
# geo                 object
# provider            object
# name                object
# decimalLongitude    object
# decimalLatitude     object
# occurrenceID        object
# common_name         object
# basis               object
# dtype: object

# %% [markdown]
# ## Exercise:
# * Extract the first 500 red wolf (*"Canis rufus"*) records from the BISON API.
# * Can you create a table listing the records collected by the `University of Kansas Biodiversity Institute`?
# * *Challenge*: Can you create a table listing all the records collected in North Carolina?

# %%
#Grab first 500 red wolf records
urlCr = 'http://bison.usgs.gov/api/search.json'
paramsCr = {'species':'Canis rufus',
          'type':'scientific_name',
          'start':'0',
          'count':'500'
         }
#Send the request to the server and store the response as a variable
responseCr = requests.get(urlCr,paramsCr)
#Convert the response 
dataCr = responseCr.json()

# %%
# convert to a df
dfCr = pd.DataFrame(dataCr['data'])
# grab records of interest
dfCr.query("provider == 'University of Kansas Biodiversity Institute'")
# Out:
#      geo                                     provider         name  \
# 30   Yes  University of Kansas Biodiversity Institute  Canis rufus
# 54   Yes  University of Kansas Biodiversity Institute  Canis rufus
# 67   Yes  University of Kansas Biodiversity Institute  Canis rufus
# 428  Yes  University of Kansas Biodiversity Institute  Canis rufus
# 430  Yes  University of Kansas Biodiversity Institute  Canis rufus
# 472  Yes  University of Kansas Biodiversity Institute  Canis rufus
#
#     occurrenceID common_name     basis    decimalLongitude     decimalLatitude
# 30     686333137    Red Wolf  Specimen  -96.57499694824219    29.5310001373291
# 54     686389327    Red Wolf  Specimen   -95.1777572631836  29.249670028686523
# 67     686356790    Red Wolf  Specimen    -97.074951171875  27.816740036010742
# 428    686333147    Red Wolf  Specimen  -96.57499694824219    29.5310001373291
# 430    686389328    Red Wolf  Specimen   -95.1777572631836  29.249670028686523
# 472    686354334    Red Wolf  Specimen   -96.6449966430664  29.594999313354492

# %%
# check for a state key
dataCr.keys()
dataCr['states']
#dfCrSt = pd.DataFrame(dataCr['states'])
# not there yet!
# Out:
# {'extent': {'miny': 24.396308000324215,
#   'minx': -124.84897399961686,
#   'maxy': 49.38435799996468,
#   'maxx': -74.98628199981302},
#  'total': 17,
#  'data': {'North Carolina': {'total': '56', 'fips': '37'},
#   'Indiana': {'total': '1', 'fips': '18'},
#   'Oklahoma': {'total': '1', 'fips': '40'},
#   'Tennessee': {'total': '1', 'fips': '47'},
#   'Minnesota': {'total': '1', 'fips': '27'},
#   'California': {'total': '3', 'fips': '06'},
#   'Florida': {'total': '17', 'fips': '12'},
#   'Alabama': {'total': '1', 'fips': '01'},
#   'Arkansas': {'total': '5', 'fips': '05'},
#   'Washington': {'total': '2', 'fips': '53'},
#   'Mississippi': {'total': '3', 'fips': '28'},
#   'New Mexico': {'total': '1', 'fips': '35'},
#   'Texas': {'total': '86', 'fips': '48'},
#   'Illinois': {'total': '2', 'fips': '17'},
#   'Missouri': {'total': '4', 'fips': '29'},
#   'Louisiana': {'total': '46', 'fips': '22'},
#   'Maryland': {'total': '1', 'fips': '24'}},
#  'legend': {'0': '0 - 5',
#   '3': '15 - 20',
#   '15': '75 - 86',
#   '8': '40 - 45',
#   '10': '50 - 55'}}
